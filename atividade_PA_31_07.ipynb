# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/atividade_PA_31_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome= str(input("Insira seu nome"))
idade= int(input("Insira sua idade"))
cidade= str(input("Insira sua cidade"))
print (f"Seu nome é {nome}, mora em {cidade} e tem {idade} anos.")
# Out:
# Insira seu nomeaquiles
# Insira sua idade15
# Insira sua cidaderibeirão pires
# Seu nome é aquiles, mora em ribeirão pires e tem 15 anos.

# %%
num= int(input("Diga um número"))
print (f"{num};{num-1};{num+1}")
# Out:
# Diga um número15
# 15;14;16

# %%
num1= (int(input("Diga um numero")))
num2= (int(input("Diga outro numero")))
print (f"Soma:{num1 + num2}")
print (f"Subtração:{num1 - num2}")
print (f"Multiplicação:{num1 * num2}")
print (f"Divisão:{num1 / num2}")
# Out:
# Diga um numero4
# Diga outro numero2
# Soma:6
# subtração:2
# Multiplicação:8
# Divisão:2.0

# %%
nota1= float(input("Qual a sua nota?"))
nota2= float(input("Qual a sua nota?"))
nota3= float(input("Qual a sua nota?"))
media = ((nota1 + nota2 + nota3)/3)
if media >= 7:
  print ("Aprovado")
elif media >=5 and media<= 6.9:
  print("Recuperação")
elif media <5:
  print("Reprovado")
else:
  print("Media incorreta")
# Out:
# Qual a sua nota?4
# Qual a sua nota?4
# Qual a sua nota?4
# Reprovado

# %%
tc= float(input("Digite a temperatura em graus celsius"))
tf=(tc * (9/5)) + 32
print (tf)
# Out:
# Digite a temperatura em graus celsius153
# 307.40000000000003

# %%
base= float(input("Diga quanto vale a base do retangulo"))
altura= float(input("Diga quanto vale a altura do retangulo"))
print (f"A área do seu retangulo é igual a:{base * altura}")
# Out:
# Diga quanto vale a base do retangulo10
# Diga quanto vale a altura do retangulo20
# A área do seu retangulo é igual a:200.0

# %%
num= int(input("Digite um numero"))
if num % 2 == 0:
  print ("Esse numero é par")
else:
  print ("Esse número é impar")
# Out:
# Digite um numero3
# Esse número é impar

# %%
num1= int(input("Digite um número"))
num2= int(input("Digite um número"))
num3= int(input("Digite um número"))
if num1> num2 and num1 > num3:
  print (f"{num1} é o maior")
elif num2> num1 and num2> num3:
  print (f"{num2} é o maior")
elif num3 > num1 and num3>num2:
  print (f"{num3} é o maior")
else:
  print ("Algo deu errado")
# Out:
# Digite um número3
# Digite um número4
# Digite um número1
# 4 é o maior

# %%
num = int(input("Digite fale um número :"))
if num >= 0 and num <= 10:
  for i in range (0, 11):
    print (f"{i} * {num}  = {i * num}")
else:
  print ("Número inválido")
# Out:
# Digite fale um número :5
# 0 * 5  = 0
# 1 * 5  = 5
# 2 * 5  = 10
# 3 * 5  = 15
# 4 * 5  = 20
# 5 * 5  = 25
# 6 * 5  = 30
# 7 * 5  = 35
# 8 * 5  = 40
# 9 * 5  = 45
# 10 * 5  = 50

# %%
#Calculadora com 4 operações
#Op1 - somar
#Op2 - subtrair
#Op3 -multiplicar
#Op4 -divisão
#Op5 - sair
opcao= 0
a= 0
b= 0

print( "~" * 20)
print("Op1 - somar")
print("Op2 - subtrair")
print("Op3 -multiplicar")
print("Op4 -divisão")
print("Op5 - sair")
print( "~" * 20)
while opcao != 5:
    opcao= int(input("Digite uma opção de 1 a 4 ou 5 para sair: "))
    if opcao == 1:
      a= int(input("Digite o número : "))
      b= int(input("Digite o número : "))
      print(f"Total da soma ={a + b}")
    elif opcao ==2:
      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da subtração={a-b}")
    elif opcao ==3:
      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da multiplição={a*b}")
    elif opcao ==4:
      a=int(input("Digite o número : "))
      b=int(input("Digite o número : "))
      print(f"Total da divisão= {a/b}")
    elif opcao ==5:
      break
# Out:
# ~~~~~~~~~~~~~~~~~~~~
# Op1 - somar
# Op2 - subtrair
# Op3 -multiplicar
# Op4 -divisão
# Op5 - sair
# ~~~~~~~~~~~~~~~~~~~~
# Digite uma opção de 1 a 4 ou 5 para sair: 5
