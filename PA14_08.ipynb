# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/PA14_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id= int(input("Digite a sua idade"))
if id >= 18:
  print ("Você tem idade o suficiente para tirar sua carteira")
else:
  print ("Você ainda não tem idade o suficiente para tirar sau carteira.")

# %%
num= int(input("Digite um numero"))
if num % 2 == 0:
  print ("Esse numero é par")
else:
  print ("Esse número é impar")

# %%
num1= int(input("Digite um número"))
num2= int(input("Digite um número"))
if num1> num2 and num1 > num3:
  print (f"{num1} é o maior")
elif num2> num1 and num2> num3:
  print (f"{num2} é o maior")
else:
  print ("Algo deu errado")

# %%
nota1= float(input("Qual a sua nota?"))
media = ((nota1))
if media >= 7:
  print ("Aprovado")
elif media >=5 and media<= 6.9:
  print("Recuperação")
elif media <5:
  print("Reprovado")
else:
  print("Media incorreta")
# Out:
# Qual a sua nota?6
# Recuperação

# %%
val= float(input("Digite o valor da compra"))
if val >= 100:
  print(f"A sua compra tem 10% de desconto, vai te custar{val * 0.9} Reais")
else:
  print(f"A sua compra vai custar {val} Reais")
# Out:
# Digite o valor da compra110
# A sua compra tem 10% de desconto, vai te custar99.0 Reais

# %%
num = float(input("Digite um número: "))

if num > 0:
  print(f"O número {num} é positivo.")
elif num < 0:
  print(f"O número {num} é negativo.")
else:
  print(f"O número {num} é zero.")
# Out:
# Digite um número: 0
# O número 0.0 é zero.

# %%
id= int(input("Diga sua idade"))
if id < 12:
  print ("Você é criança")
elif id >= 12 and id <17:
  print ("Você é adolescente")
elif id >= 18 and id <59:
  print ("Você é adulto")
else:
  print ("Você é idoso")

# %%
nota1= float(input("Qual a sua nota?"))
nota2= float(input("Qual a sua nota?"))
media = ((nota1 + nota2 )/2)
if media >= 7:
  print ("Aprovado")
elif media >=5 and media<= 6.9:
  print("Recuperação")
elif media <5:
  print("Reprovado")
else:
  print("Media incorreta")

# %%
user= str(input("Insira seu usuário"))
senha= str(input("Insira sua senha"))
if senha == "1234" and user == "admin":
  print ("Login realizado com sucesso")
else:
  print ("Usuário ou senha incorretos")
# Out:
# Insira seu usuárioasas
# Insira sua senha1212
# Usuário ou senha incorretos

# %%
peso= float(input("Diga seu peso em quilos"))
altura= float(input("Diga sua altura em metros"))
imc= peso/(altura * altura)
if imc < 18.5:
  print ("Você está abaixo do peso")
elif imc >= 18.5 and imc< 24.9:
  print ("Você está no peso normal")
elif imc >= 25 and imc< 29.9:
  print ("Você está com sobrepeso")
else:
  print ("Você está obeso")
# Out:
# Diga seu peso em quilos1.95
# Diga sua altura em metros240
# Você está abaixo do peso
