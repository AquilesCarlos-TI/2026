# %%
# 1. Guardando as informações nas caixinhas (Variáveis)
nome_do_aluno = "Aquiles"
idade = 17
curso = "TI - ETEC"
materia_favorita = "matematica"

# 2. Exibindo as informações (O famoso Print)
print("Olá, mundo!")
print("Meu nome é:", nome_do_aluno)
print("a minha materia favoria é:", materia_favorita)
print("Estou estudando:", curso)
# Out:
# Olá, mundo!
# Meu nome é: Aquiles
# a minha materia favoria é: matematica
# Estou estudando: TI - ETEC
