# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/PA18_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas= ["Maçã", "Banana", "Laranja", "Morango"]
print (frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kayra"]
print (nomes[0])
print (nomes [3])
# Out:
# Rebeca
# Kayra

# %%
cores = ["vermelho", "azul", "verde"]
cores[1]= ("amarelo")
print (cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
alunos = ["nicolas", "wendel", "pyetra"]
alunos.append ("petros")
print (alunos)
# Out:
# ['nicolas', 'wendel', 'pyetra', 'petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)

# %%
numeros = (10, 20, 30, 40, 50)
print(numeros[0])
print(numeros[2])
print(numeros[-1])

# %%
aluno = ("João", 20, "Engenharia")
print("Nome:", aluno[0])
print("Idade:", aluno[1])
print("Curso:", aluno[2])

# %%
cores = ("vermelho", "azul", "verde")

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)
quantidade = numeros.count(2)
print("O número 2 aparece", quantidade, "vezes.")
