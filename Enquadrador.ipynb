# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/Enquadrador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto= input("Digite algo para enquadrar.")
tamanho= len(texto)
linha = "-" * (tamanho + 4)
print (linha)
print("| " + texto + " |")
print (linha)
