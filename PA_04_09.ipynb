# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/PA_04_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fazer_cafe():
  print ("Preparando café...")
  print ("Seu café está pronto!")
fazer_cafe()
# Out:
# Preparando café...
# Seu café está pronto!

# %%
def cumprimentar(nome):
    print("Olá",nome)
cumprimentar("Aquiles")
# Out:
# Olá Aquiles

# %%
def cumprimentar(nome):
    print("Olá", nome)
cumprimentar ("Mundo")
# Out:
# Olá Mundo

# %%
def mensagem(curso):
  print("Bem vindo ao curso de", curso)
  print("Bem vindo ao curso de", curso)
mensagem ("Programação")
# Out:
# Bem vindo ao curso de Programação
# Bem vindo ao curso de Programação

# %%
def somar(soma):
  print ("10 + 20 =", soma )
somar (10 + 20)
# Out:
# 10 + 20 = 30

# %%
def subtrair(menos):
  print ("50 - 15 =", menos )
subtrair (50 - 15)
# Out:
# 50 - 15 = 35

# %%
def multiplicar(multi):
  print ("8 * 7 = ", multi)
multiplicar (8 * 7)
# Out:
# 8 * 7 =  56

# %%
def cumprimentar (cump):
  print ("Olá", cump)
cumprimentar ("Maria")
cumprimentar ("Ana")
cumprimentar ("Antonio")
# Out:
# Olá Maria
# Olá Ana
# Olá Antonio

# %%
def dobro (num):
  print ("o dobro é", num)
dobros = int(input("Digite um número"))
dobro (dobros * 2)
# Out:
# Digite um número20
# o dobro é 40

# %%
def mostrar_idade(idade):
  print("Você tem", idade, "anos")
mostrar_idade (18)
mostrar_idade (15)
mostrar_idade (17)
# Out:
# Você tem 18 anos
# Você tem 15 anos
# Você tem 17 anos

# %%
def verificar_numero(numero):
   print("Esse número é: ", numero)
num= int(input("Digite um número" ))
if num == 0:
  verificar_numero("zero")
elif num < 0:
  verificar_numero("negativo")
elif num > 0:
  verificar_numero("positivo")
# Out:
# Digite um número-0
# Esse número é:  zero

# %%
def calcular_media(nota1, nota2):
  print ("Nota 1:", nota1)
  print ("Nota 2:", nota2)
  print ("Media:", (nota1 + nota2) / 2)
calcular_media (8, 9)
# Out:
# Nota 1: 8
# Nota 2: 9
# Media: 8.5
