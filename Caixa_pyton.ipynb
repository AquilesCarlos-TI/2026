# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/Caixa_pyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item = input ("O que você quer colocar dentro da caixa?")
print ("{-------------------------}")
print ("{                         }")
print ("{   CONTEUDO:" + item       )
print ("{                         }")
print ("{-------------------------}")
# Out:
# O que você quer colocar dentro da caixa?Maçã
# {-------------------------}
# {                         }
# {   CONTEUDO:Maçã
# {                         }
# {-------------------------}
