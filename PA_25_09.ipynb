# %% [markdown]
# <a href="https://colab.research.google.com/github/AquilesCarlos-TI/2026/blob/main/PA_25_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno={
    "Nome":"Ana",
    "Idade": 17,
    "Curso":"Ciência da computação"
}
print(aluno)
# Out:
# Ana

# %%
aluno={
    "Nome":"Ana",
    "Idade": 17,
    "Curso":"Ciência da computação"
}
print(aluno["Nome"])
print(aluno["Idade"])
print(aluno["Curso"])

# %%
produto={
    "Nome":"Mouse",
    "Preço": 45,
    "Estoque":150
}
produto["Preço"]= 50
print(produto)
# Out:
# {'Nome': 'Mouse', 'Preço': 50, 'Estoque': 150}

# %%
aluno={
    "Nome":"Ana",
    "Idade": 17,
}
aluno["Curso"]= "Informática"
print (aluno)
# Out:
# {'Nome': 'Ana', 'Idade': 17, 'Curso': 'Informática'}

# %%
filme={
    "titulo":"pânico 2",
    "ano": 1997,
    "genero":"Terror",
    "nota": 7.8
}
print(filme["titulo"])
print(filme["ano"])
print(filme["genero"])
print(filme["nota"])
# Out:
# pânico 2
# 1997
# Terror
# 7.8

# %%
numeros={
    1,2,3,4,5
}
print (numeros)

# %%
numeros={
    1,2,2,3,3,4,5
}
print (numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
frutas={
    "maçã","banana","laranja"
}
frutas.add("morango")
print(frutas)
# Out:
# {'morango', 'maçã', 'banana', 'laranja'}

# %%
cores={
    "vermelho","azul","verde","amarelo"
}
cores.remove("vermelho")
print(cores)
# Out:
# {'amarelo', 'verde', 'azul'}

# %%
nomes={
    "yris","luna","luna","maite","yris","ravi","gael","theo","theo"
}
print(nomes)
# Out:
# {'luna', 'theo', 'maite', 'gael', 'yris', 'ravi'}
